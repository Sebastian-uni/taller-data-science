# %% [markdown]
# ¿Cuál es el tipo de dato del resultado de: 6 / 2?
# RTA: float

# %%
# tu código
type(6/2)
# Out:
# float

# %% [markdown]
# ¿Qué tipo de resultado tiene la operación: 6 // 2?
# RTA: int

# %%
# tu código
type(6//2)
# Out:
# int

# %% [markdown]
# ¿Cuál es el tipo de resultado de: "Hola, mundo!"? RTA: str

# %%
# tu código
type('Hola, mundo!')
# Out:
# str

# %% [markdown]
# Escribe el código para convertir el siguiente número que representa el ID de empleado "1001" a un número entero.

# %%
# tu código
ID_de_empleado = '1001'
int(ID_de_empleado)
# Out:
# 1001

# %% [markdown]
# Escribe el código para convertir este número que representa el valor financiero "1234.56" a un número de punto flotante.

# %%
# tu código
Valor_financiero = 1234.56
float(Valor_financiero)
# Out:
# 1234.56

# %% [markdown]
# Escribe el código para convertir este número de teléfono 123-456-7890 a una cadena de texto.

# %%
# tu código
numero_de_telefono = 1234567890
numero_de_telefono_str = str(numero_de_telefono)
print(numero_de_telefono_str[0:3]+"-"+numero_de_telefono_str[3:6]+"-"+numero_de_telefono_str[6:10])
# Out:
# 123-456-7890

# %% [markdown]
# Escribe una expresión para sumar 30 y 20 y restar 40.

# %%
# tu código
resultado = 30 + 20 - 40

print(resultado)
# Out:
# 10

# %% [markdown]
# Escribe una expresión para restar 5 de 55 y dividir el resultado entre 10.

# %%
# tu código
resultado = (5-55)/10
print(resultado)
# Out:
# -5.0

# %% [markdown]
# Escribe una expresión para multiplicar 6 por 10 y dividir el resultado entre 12.

# %%
# tu código
resultado = (6*10)/10
print(resultado)
# Out:
# 6.0

# %% [markdown]
# ¿Cuál es el valor de x donde x = 3 + 2 * 2?

# %%
# tu código
x = 3 + 2 * 2
print(x)
# Out:
# 7

# %% [markdown]
# ¿Cuál es el valor de y donde y = (3 + 2) * 2?

# %%
# tu código

y = (3 + 2) * 2
print(y)
# Out:
# 10

# %% [markdown]
# ¿Cuál es el valor de z donde z = x + y?

# %%
# tu código
z = x + y
print(z)
# Out:
# 17
